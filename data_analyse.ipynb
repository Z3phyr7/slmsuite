# %%
import numpy as np
from sub_funcs import *

# %%
gaussian_params = read_gaussian_params_from_file(filename='test.txt')
spot1,spot2 = sort_spot(gaussian_params=gaussian_params, x1=2868,x2=1007, vibration_range=50, by_x= True)
deviation1 = consecutive_anlys_1st(spot_list=spot1)
deviation2 = consecutive_anlys_1st(spot_list=spot2)
print("deviation of 1 : {}".format(deviation1))
print("deviation of 2 : {}".format(deviation2))
# Out:
# deviation of 1 : 0.34752667512088775
# deviation of 2 : 0.31725230306796487

# %%
len(gaussian_params)
# Out:
# 15729

# %%
spread1 = spread_anlys(spot_list=spot1)
spread2 = spread_anlys(spot_list=spot2)

# %%
print("spread 1: {}".format(spread1))
print("spread 2: {}".format(spread2))
# Out:
# spread 1: 3.509747622694117
# spread 2: 1.5686115391169868

# %%
drift_visualisation(spot_list=spot1)
drift_visualisation(spot_list=spot2)

# %%
XY_visualisation(spot_list=spot1)
XY_visualisation(spot_list=spot2)

# %%
x1_list = [spot['x0'] for spot in spot1]
max_x1 = max(x1_list)
y1_list = [spot['y0'] for spot in spot1]
max_y1 = max(y1_list)
print("max x1: {}".format(max_x1))
print("max y1: {}".format(max_y1))
# Out:
# max x1: 2870.609144772504
# max y1: 615.2198191101505
